# %%
import cv2
import matplotlib.pyplot as plt
from deepface import DeepFace
img= cv2.imread('happyboy.jpg')
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# age_model_weights.h5 will be downloaded...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8452/1102709503.py in <module>
# ----> 1 predictions = DeepFace.analyze(img)
#
# ~\anaconda3\lib\site-packages\deepface\DeepFace.py in analyze(img_path, actions, models, enforce_detection, detector_backend, prog_bar)
#     352
#     353         if 'age' in actions and 'age' not in built_models:
# --> 354                 models['age'] = build_model('Age')
#     355
#     356         if 'gender' in actions and 'gender' not in built_models:
#
# ~\anaconda3\lib\site-packages\deepface\DeepFace.py in build_model(model_name)
#      61                 model = models.get(model_name)
#      62                 if model:
# ---> 63                         model = model()
#      64                         model_obj[model_name] = model
#      65                         #print(model_name," built")
#
# ~\anaconda3\lib\site-packages\deepface\extendedmodels\Age.py in loadModel(url)
#      47
#      48                 output = home+'/.deepface/weights/age_model_weights.h5'
# ---> 49                 gdown.download(url, output, quiet=False)
#      50
#      51         age_model.load_weights(home+'/.deepface/weights/age_model_weights.h5')
#
# ~\anaconda3\lib\site-packages\gdown\download.py in download(url, output, quiet, proxy, speed, use_cookies, verify, id, fuzzy, resume)
#     200     if output_is_path:
#     201         existing_tmp_files = []
# --> 202         for file in os.listdir(osp.dirname(output) or "."):
#     203             if file.startswith(osp.basename(output)):
#     204                 existing_tmp_files.append(osp.join(osp.dirname(output), file))
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\lenovo/.deepface/weights'

# %%
predictions
type(predictions);
predictions['dominant_emotion']
faceCascade= cv2.CascadeClassifier(cv2.data.haarcascades='haarcascade_frontalface_default.xml')
grey=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
faces=faceCascade.detectMultiScale(gray,1.2,4)
for(x,y,w,h)in faces:
    cv2.rectangle(img, (x,y), (x+w, y+h), (0,255,0), 2)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img, predictions['dominant_emotion'],(0,50),font, 1,(0,0,255),2,cv2.LINE_4);
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

img=cv2.imread('sadface.jpg')
predictions = DeepFace.analyze(img)
predictions
